# %%
name="Tarique"

# %%
name
# Out:
# 'Tarique'

# %%
name.upper()
# Out:
# 'TARIQUE'

# %%
name.lower()
# Out:
# 'tarique'

# %%
name.endswith('que')
# Out:
# True

# %%
name.endswith('moh')
# Out:
# False

# %%
name1="Mohammad Tarique Atique"

# %%
name1
# Out:
# 'Mohammad Tarique Atique'

# %%
    len(name1)
# Out:
# 23

# %%
name1[0:9]
# Out:
# 'Mohammad '

# %%
name1[-16:-1]
# Out:
# 'd Tarique Atiqu'

# %%
name1[-23:-1]
# Out:
# 'Mohammad Tarique Atiqu'
