# %%
a = 16
b = 6

# %%
a+b
# Out:
# 22

# %%
a-b
# Out:
# 10

# %%
a*b
# Out:
# 96

# %%
a//b
# Out:
# 2

# %%
a**b
# Out:
# 16777216

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# False

# %%
a==b
# Out:
# False

# %%
a+=b

# %%
a
# Out:
# 3

# %%
a//=b

# %%
a
# Out:
# 3

# %%
a//b
# Out:
# 2

# %%
a=24
b=8

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
a == b
# Out:
# False

# %%
a and b
# Out:
# 8

# %%
a or b
# Out:
# 24

# %%
a != b
# Out:
# True

# %%
not b
# Out:
# False

# %%
not a
# Out:
# False
