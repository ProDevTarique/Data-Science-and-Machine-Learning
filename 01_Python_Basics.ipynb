# %%
a = 56

# %%
b = 49

# %%
a+b
# Out:
# 105

# %%
p = "65280"

# %%
q = "87670"

# %%
p+q
# Out:
# '6528087670'

# %%
int(p) + int(q)
# Out:
# 152950

# %%
type(a)
# Out:
# int

# %%
type(q)
# Out:
# str
